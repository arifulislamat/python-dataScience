# %% [markdown]
# ### Importing libary

# %%
# Import Libraries
import pandas as panda

# Import dataset
rawData = "dataset/covid19.csv"
dataFrame = panda.read_csv(rawData)

# %%
dataFrame.head(5)
# Out:
#              Date  dhaka  faridpur  gazipur  gopalganj  kishorganj  madaripur  \
# 0  April 15, 2020    546         2       53          9          17         19
# 1  April 16, 2020    636         2       98         17          33         23
# 2  April 17, 2020    768         2      117         17          33         23
# 3  April 18, 2020    877         4      161         21          54         25
# 4  April 19, 2020   1014         4      173         21          77         26
#
#    manikganj  munshiganj  narayanganj  ...  kurigram  lalmonirhat  nilphamari  \
# 0          5          21          214  ...         2            2           6
# 1          5          21          255  ...         2            2           6
# 2          5          27          289  ...         2            2           6
# 3          6          33          309  ...         2            2           9
# 4          6          33          386  ...         2            2           9
#
# ...

# %%
# Working with different built-in methods
dataFrame.dtypes
# Out:
# Date            object
# dhaka            int64
# faridpur         int64
# gazipur          int64
# gopalganj        int64
#                  ...
# thakurgaon       int64
# habiganj         int64
# moulvi bazar     int64
# shunamganj       int64
# sylhet           int64
# Length: 65, dtype: object

# %%
dataFrame.describe()
# Out:
#               dhaka    faridpur      gazipur   gopalganj  kishorganj  \
# count     52.000000   52.000000    52.000000   52.000000   52.000000
# mean    8286.326923   69.076923   466.634615   91.903846  190.788462
# std     6143.961706   88.282045   276.946235   73.244757   54.485233
# min      546.000000    2.000000    53.000000    9.000000   17.000000
# 25%     3021.750000    9.000000   317.250000   45.000000  193.250000
# 50%     7138.500000   24.000000   335.500000   57.000000  203.500000
# 75%    10878.000000   69.000000   535.000000  115.000000  207.000000
# max    21294.000000  348.000000  1163.000000  287.000000  264.000000
#
#         madaripur   manikganj  munshiganj  narayanganj  narshingdi  ...  \
# count   52.000000   52.000000   52.000000    52.000000   52.000000  ...
# mean    67.846154   53.076923  312.057692  1246.173077  156.057692  ...
# std     45.815651   53.438565  280.383939   630.354669   33.002325  ...
# ...

# %%
dataFrame.isnull().sum()
# Out:
# Date            0
# dhaka           0
# faridpur        0
# gazipur         0
# gopalganj       0
#                ..
# thakurgaon      0
# habiganj        0
# moulvi bazar    0
# shunamganj      0
# sylhet          0
# Length: 65, dtype: int64

# %%
# Total case effect case in Madaripur district
 
dataFrame.madaripur.sum()
# Out:
# 3528

# %%
dataFrame.mean()
# Out:
# C:\Users\ariful\AppData\Local\Temp\ipykernel_49584\3390282323.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataFrame.mean()
# dhaka           8286.326923
# faridpur          69.076923
# gazipur          466.634615
# gopalganj         91.903846
# kishorganj       190.788462
#                    ...
# thakurgaon        28.134615
# habiganj          85.884615
# moulvi bazar      40.019231
# shunamganj        49.826923
# sylhet           105.788462
# Length: 64, dtype: float64

# %%
dataFrame.corr()
# Out:
# C:\Users\ariful\AppData\Local\Temp\ipykernel_49584\3497904997.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataFrame.corr()
#                  dhaka  faridpur   gazipur  gopalganj  kishorganj  madaripur  \
# dhaka         1.000000  0.935695  0.935867   0.961283    0.716944   0.955134
# faridpur      0.935695  1.000000  0.953916   0.984333    0.570853   0.983823
# gazipur       0.935867  0.953916  1.000000   0.976497    0.688184   0.959795
# gopalganj     0.961283  0.984333  0.976497   1.000000    0.643059   0.976205
# kishorganj    0.716944  0.570853  0.688184   0.643059    1.000000   0.645882
# ...                ...       ...       ...        ...         ...        ...
# thakurgaon    0.978040  0.945515  0.909406   0.953142    0.692527   0.956187
# ...

# %%
dataFrame['dhaka'].value_counts().head(5)
# Out:
# 10878    6
# 7409     3
# 9855     2
# 546      1
# 636      1
# Name: dhaka, dtype: int64
